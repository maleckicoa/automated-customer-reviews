# %%
import pandas as pd
from pathlib import Path
import kagglehub
pd.set_option('display.max_columns', None)

# Download all files
path = kagglehub.dataset_download("datafiniti/consumer-reviews-of-amazon-products")
csv_paths = list(Path(path).glob("*.csv"))


dfs = [pd.read_csv(p) for p in csv_paths]
df = pd.concat(dfs, ignore_index=True)

df = df.drop_duplicates(
    subset=['id', 'dateAdded', 'dateUpdated', 'reviews.text', 'reviews.title', 'reviews.username'],
    keep='first'
)

print(df.shape)
# Out:
# Found CSV files: [PosixPath('/Users/aleksamihajlovic/.cache/kagglehub/datasets/datafiniti/consumer-reviews-of-amazon-products/versions/5/Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv'), PosixPath('/Users/aleksamihajlovic/.cache/kagglehub/datasets/datafiniti/consumer-reviews-of-amazon-products/versions/5/1429_1.csv'), PosixPath('/Users/aleksamihajlovic/.cache/kagglehub/datasets/datafiniti/consumer-reviews-of-amazon-products/versions/5/Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv')]
# /var/folders/j5/nn2q62291v59dvdxyx4zf3_c0000gn/T/ipykernel_87622/3315511673.py:14: DtypeWarning: Columns (1,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = [pd.read_csv(p) for p in csv_paths]
# (67896, 27)

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 3  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 4  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 3  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 4  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# ...

# %%
dup_count = df.duplicated(subset=['id', 'dateAdded', 'dateUpdated','reviews.text', 'reviews.title', 'reviews.username']).sum()
print(f"Number of duplicate rows (by id, dateAdded, dateUpdated): {dup_count}")
# Out:
# Number of duplicate rows (by id, dateAdded, dateUpdated): 96
